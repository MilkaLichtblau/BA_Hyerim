# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#importing the data from csv
path='LSAT.csv'
data = pd.read_csv(path, delimiter=',')

#Generating the correlation heatmap
f, ax = plt.subplots(figsize=(15, 10)) 
corr = data.corr()
print corr
hm = sns.heatmap(corr, annot=True, ax=ax, cmap= "coolwarm", fmt='.2f',linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Generated Data Heatmap', fontsize=8)
f.savefig('Generated Data Heatmap',pad_inches=1, bbox_inches='tight')
# Out:
#              sex    race_0    race_1    race_2    race_3    race_4    race_5  \
# sex     1.000000 -0.075167 -0.005953  0.022605  0.093923  0.012143 -0.001571
# race_0 -0.075167  1.000000 -0.154280 -0.458690 -0.570970 -0.345646 -0.307885
# race_1 -0.005953 -0.154280  1.000000 -0.013569 -0.016890 -0.010225 -0.009108
# race_2  0.022605 -0.458690 -0.013569  1.000000 -0.050217 -0.030400 -0.027079
# race_3  0.093923 -0.570970 -0.016890 -0.050217  1.000000 -0.037841 -0.033707
# race_4  0.012143 -0.345646 -0.010225 -0.030400 -0.037841  1.000000 -0.020405
# race_5 -0.001571 -0.307885 -0.009108 -0.027079 -0.033707 -0.020405  1.000000
# race_6 -0.000991 -0.266610 -0.007887 -0.023448 -0.029188 -0.017670 -0.015739
# race_7  0.001119 -0.162667 -0.004812 -0.014307 -0.017809 -0.010781 -0.009603
# LSAT   -0.078871  0.317456 -0.046954 -0.015007 -0.337502 -0.082644 -0.095058
# UGPA    0.135351  0.182990 -0.043220 -0.004114 -0.200915 -0.032182 -0.063465
# ZFYA   -0.042245  0.285825 -0.050462 -0.082769 -0.248068 -0.066610 -0.087089
#
#           race_6    race_7      LSAT      UGPA      ZFYA
# sex    -0.000991  0.001119 -0.078871  0.135351 -0.042245
# race_0 -0.266610 -0.162667  0.317456  0.182990  0.285825
# race_1 -0.007887 -0.004812 -0.046954 -0.043220 -0.050462
# race_2 -0.023448 -0.014307 -0.015007 -0.004114 -0.082769
# race_3 -0.029188 -0.017809 -0.337502 -0.200915 -0.248068
# race_4 -0.017670 -0.010781 -0.082644 -0.032182 -0.066610
# race_5 -0.015739 -0.009603 -0.095058 -0.063465 -0.087089
# race_6  1.000000 -0.008316 -0.023769 -0.005282 -0.017176
# race_7 -0.008316  1.000000 -0.051059 -0.035060 -0.055162
# LSAT   -0.023769 -0.051059  1.000000  0.247945  0.284531
# UGPA   -0.005282 -0.035060  0.247945  1.000000  0.186165
# ZFYA   -0.017176 -0.055162  0.284531  0.186165  1.000000
